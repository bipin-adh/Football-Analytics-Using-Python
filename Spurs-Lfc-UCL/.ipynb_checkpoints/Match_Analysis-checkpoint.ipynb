# %% [markdown]
# # Spurs vs Liverpool . UCL Final (First Half Shots)
#
# ### Data is used from Statsbomb (competitions , events , matches):
#
# * competitions - eg : UCL , worldcup , etc
# * matches - take in competition id and see the matches of the required competition.
# * events - take match id and visualize and analyze all the detailed events of every min (passes, shots,build up play,etc)

# %%
import json
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
from FCPython import createPitch

# %%
# point to local directory of football data.
BASE_DIR = '../statsbomb-data/open-data/data'

# %%
# Load the competition file .
with open(BASE_DIR +'/competitions.json') as f:
    competitions = json.load(f)

# %%
# Create a dataframe of the json file
competitions_df = pd.read_json(BASE_DIR + '/competitions.json')

# %%
# Filter and take out the champions league competition id.
competitions_df[competitions_df['competition_name'] == 'Champions League'].head()
# Out:
#    competition_id  season_id country_name  competition_name  \
# 0              16          4       Europe  Champions League
# 1              16          1       Europe  Champions League
# 2              16          2       Europe  Champions League
# 3              16         27       Europe  Champions League
# 4              16         26       Europe  Champions League
#
#   competition_gender season_name               match_updated  \
# 0               male   2018/2019  2020-02-27T12:19:39.458017
# 1               male   2017/2018  2020-06-11T01:24:40.306618
# 2               male   2016/2017  2020-06-10T22:06:56.555602
# 3               male   2015/2016  2020-06-10T20:02:56.222690
# 4               male   2014/2015  2020-06-10T17:04:18.637515
#
#               match_available
# 0  2020-02-27T12:19:39.458017
# 1  2020-06-11T01:24:40.306618
# 2  2020-06-10T22:06:56.555602
# 3  2020-06-10T20:02:56.222690
# 4  2020-06-10T17:04:18.637515

# %%
# UEFA Champions League 2018/2019 has competition ID = 16
competition_id = 16

# %%
# Load spurs vs liverpool json file from the list of final matches(json) of Champions League. 

matches = pd.read_json(BASE_DIR+'/matches/'+
                      str(competition_id)+'/4.json')

# %%
# Check the list of matches in the file
matches
# Out:
#    match_id  match_date      kick_off  \
# 0     22912  2019-06-01  21:00:00.000
#
#                                          competition  \
# 0  {'competition_id': 16, 'country_name': 'Europe...
#
#                                          season  \
# 0  {'season_id': 4, 'season_name': '2018/2019'}
#
#                                            home_team  \
# 0  {'home_team_id': 38, 'home_team_name': 'Totten...
#
#                                            away_team  home_score  away_score  \
# 0  {'away_team_id': 24, 'away_team_name': 'Liverp...           0           2
#
#   match_status                last_updated  \
# 0    available  2019-12-16T23:09:16.168756
#
#                                             metadata  match_week  \
# 0  {'data_version': '1.1.0', 'shot_fidelity_versi...          13
#
#              competition_stage
# 0  {'id': 26, 'name': 'Final'}

# %%
# Champions league final id : Spurs vs Liverpool
match_id = matches['match_id'][0]
match_id
# Out:
# 22912

# %% [markdown]
# # Start Match Analysis:
#
# * Importing FcPython code for pitch drawing.
# * length = 120 yards , width = 80 yards (Statsbomb data default pitch unit is in yards. While metrica sports is in metres.)

# %%
# Size of the pitch in yards.
pitchLengthX = 120
pitchWidthY = 80

# %%
home_team_required = "Liverpool"
away_team_required = "Tottenham Hotspur"

# %%
# Load in all match events data.
spursVsLfc_match = str(match_id)+'.json'

# %%
# print('/home/bpn8adh/My-Football-Analytics-Python/statsbomb-data/open-data/data/events/'+ str(match_id)+'.json')
events_df = pd.read_json(BASE_DIR+'/events/'+spursVsLfc_match)

# %%
events_df.head(34)
# events_df[events_df['possession_team'].get('name')]
# events_df['possession_team']
# Out:
#                                       id  index  period  \
# 0   c4341845-358d-43e7-9af4-9a39aa1d90f1      1       1
# 1   6001a7ed-2c00-4cb4-ba33-7ac2b7d07c40      2       1
# 2   52cdf1be-4cbd-4026-b802-e5c3dce19e9c      3       1
# 3   97668e09-1ce7-4752-912c-b3a5a1bf6013      4       1
# 4   68f1458f-6ddb-4626-82cb-6f96eaca8087      5       1
# 5   0c607c5b-7849-4da0-aa96-3a7d4475b700      6       1
# 6   fa083d31-a8b7-4f0a-9379-3233d6f01ab5      7       1
# 7   4ce9fdce-4312-46e6-a9a8-f844fc4d8d1e      8       1
# 8   2b8b28a3-6309-42c8-8f9f-d085b5ab04fd      9       1
# 9   97663e2f-a285-4714-b5f4-3e973e39c8c4     10       1
# 10  9f6bb7e9-6fbe-4419-8daf-c9734002c2de     11       1
# 11  e322ed23-23ad-42f3-a168-4bd47a792ed7     12       1
# 12  2bb36d35-9c89-4dc3-881b-6028109dc77a     13       1
# 13  ab4cdc27-8ab4-40b3-8faa-2d6acc49c30c     14       1
# 14  8324b249-04a7-4baa-a5fc-bbb112371883     15       1
# 15  01e5cf81-34c7-44c5-b529-0e4bf89897a7     16       1
# 16  12da1497-c107-4955-942c-cb10bac3ea41     17       1
# 17  51800a85-b1fd-4f2c-8dd3-4217276b4ad5     18       1
# 18  0f426aa2-a7ef-47e4-83e9-4a2b198a3651     19       1
# 19  67da3d77-14f8-4773-9e80-d43552780fdd     20       1
# 20  810866d9-26c3-4d39-8e49-d1f6b1616ae9     21       1
# 21  0f096627-1436-45d9-af56-6c1b3da1bdfb     22       1
# 22  61cd7e99-9da5-41d7-885b-8a7ce532ac0f     23       1
# 23  b800586f-eb7b-48bb-aeda-2eb7e902b81c     24       1
# 24  f8074d6a-ba1b-427b-9b3a-6805a01fbb16     25       1
# 25  216d599d-ba31-43f3-a042-5e4f5601f802     26       1
# 26  0c04ec28-2f71-4e0a-a2d7-fb881704dbd2     27       1
# 27  cef3f368-30e5-4cf4-9403-f9160a088679     28       1
# 28  023cf626-3c81-43b3-b649-f3e39743ca87     29       1
# 29  023f7bad-016e-4897-9746-d776ec7ecc07     30       1
# 30  9a07c638-53ba-4367-b830-4d44a1f2f604     31       1
# 31  20f0f86a-472c-4fdb-a2ce-4e6981bce315     32       1
# 32  55eabf2f-c8c5-4c3d-9c6d-1c6724d0e5e3     33       1
# 33  642e3db4-bfa4-4ed2-9a22-468e68bd6e0a     34       1
#
#                  timestamp  minute  second  \
# 0  2020-07-04 00:00:00.000       0       0
# 1  2020-07-04 00:00:00.000       0       0
# 2  2020-07-04 00:00:00.000       0       0
# 3  2020-07-04 00:00:00.000       0       0
# 4  2020-07-04 00:00:00.208       0       0
# 5  2020-07-04 00:00:01.875       0       1
# 6  2020-07-04 00:00:01.875       0       1
# 7  2020-07-04 00:00:03.358       0       3
# 8  2020-07-04 00:00:05.398       0       5
# 9  2020-07-04 00:00:05.398       0       5
# 10 2020-07-04 00:00:07.704       0       7
# 11 2020-07-04 00:00:07.704       0       7
# 12 2020-07-04 00:00:08.854       0       8
# 13 2020-07-04 00:00:08.854       0       8
# 14 2020-07-04 00:00:10.419       0      10
# 15 2020-07-04 00:00:10.419       0      10
# 16 2020-07-04 00:00:10.419       0      10
# 17 2020-07-04 00:00:11.107       0      11
# 18 2020-07-04 00:00:11.107       0      11
# 19 2020-07-04 00:00:14.904       0      14
# 20 2020-07-04 00:00:14.904       0      14
# 21 2020-07-04 00:00:15.700       0      15
# 22 2020-07-04 00:00:15.972       0      15
# 23 2020-07-04 00:00:15.972       0      15
# 24 2020-07-04 00:00:16.045       0      16
# 25 2020-07-04 00:00:16.779       0      16
# 26 2020-07-04 00:00:16.779       0      16
# 27 2020-07-04 00:00:17.057       0      17
# 28 2020-07-04 00:00:19.559       0      19
# 29 2020-07-04 00:00:19.559       0      19
# 30 2020-07-04 00:00:22.597       0      22
# 31 2020-07-04 00:00:22.913       0      22
# 32 2020-07-04 00:00:22.971       0      22
# 33 2020-07-04 00:01:48.568       1      48
#
#                                     type  possession  \
# 0      {'id': 35, 'name': 'Starting XI'}           1
# 1      {'id': 35, 'name': 'Starting XI'}           1
# 2       {'id': 18, 'name': 'Half Start'}           1
# 3       {'id': 18, 'name': 'Half Start'}           1
# 4             {'id': 30, 'name': 'Pass'}           2
# 5    {'id': 42, 'name': 'Ball Receipt*'}           2
# 6            {'id': 43, 'name': 'Carry'}           2
# 7             {'id': 30, 'name': 'Pass'}           2
# 8    {'id': 42, 'name': 'Ball Receipt*'}           2
# 9             {'id': 30, 'name': 'Pass'}           2
# 10   {'id': 42, 'name': 'Ball Receipt*'}           2
# 11            {'id': 30, 'name': 'Pass'}           2
# 12   {'id': 42, 'name': 'Ball Receipt*'}           2
# 13            {'id': 30, 'name': 'Pass'}           2
# 14   {'id': 42, 'name': 'Ball Receipt*'}           2
# 15             {'id': 4, 'name': 'Duel'}           2
# 16            {'id': 30, 'name': 'Pass'}           2
# 17   {'id': 42, 'name': 'Ball Receipt*'}           2
# 18            {'id': 30, 'name': 'Pass'}           2
# 19   {'id': 42, 'name': 'Ball Receipt*'}           2
# 20            {'id': 30, 'name': 'Pass'}           2
# 21        {'id': 17, 'name': 'Pressure'}           2
# 22   {'id': 42, 'name': 'Ball Receipt*'}           2
# 23           {'id': 43, 'name': 'Carry'}           2
# 24            {'id': 30, 'name': 'Pass'}           2
# 25   {'id': 42, 'name': 'Ball Receipt*'}           2
# 26           {'id': 43, 'name': 'Carry'}           2
# 27            {'id': 30, 'name': 'Pass'}           2
# 28   {'id': 42, 'name': 'Ball Receipt*'}           2
# 29           {'id': 43, 'name': 'Carry'}           2
# 30            {'id': 30, 'name': 'Pass'}           2
# 31   {'id': 42, 'name': 'Ball Receipt*'}           2
# 32  {'id': 22, 'name': 'Foul Committed'}           2
# 33            {'id': 16, 'name': 'Shot'}           3
#
#                             possession_team  \
# 0   {'id': 38, 'name': 'Tottenham Hotspur'}
# 1   {'id': 38, 'name': 'Tottenham Hotspur'}
# 2   {'id': 38, 'name': 'Tottenham Hotspur'}
# 3   {'id': 38, 'name': 'Tottenham Hotspur'}
# 4           {'id': 24, 'name': 'Liverpool'}
# 5           {'id': 24, 'name': 'Liverpool'}
# 6           {'id': 24, 'name': 'Liverpool'}
# 7           {'id': 24, 'name': 'Liverpool'}
# 8           {'id': 24, 'name': 'Liverpool'}
# 9           {'id': 24, 'name': 'Liverpool'}
# 10          {'id': 24, 'name': 'Liverpool'}
# 11          {'id': 24, 'name': 'Liverpool'}
# 12          {'id': 24, 'name': 'Liverpool'}
# 13          {'id': 24, 'name': 'Liverpool'}
# 14          {'id': 24, 'name': 'Liverpool'}
# 15          {'id': 24, 'name': 'Liverpool'}
# 16          {'id': 24, 'name': 'Liverpool'}
# 17          {'id': 24, 'name': 'Liverpool'}
# 18          {'id': 24, 'name': 'Liverpool'}
# 19          {'id': 24, 'name': 'Liverpool'}
# 20          {'id': 24, 'name': 'Liverpool'}
# 21          {'id': 24, 'name': 'Liverpool'}
# 22          {'id': 24, 'name': 'Liverpool'}
# 23          {'id': 24, 'name': 'Liverpool'}
# 24          {'id': 24, 'name': 'Liverpool'}
# 25          {'id': 24, 'name': 'Liverpool'}
# 26          {'id': 24, 'name': 'Liverpool'}
# 27          {'id': 24, 'name': 'Liverpool'}
# 28          {'id': 24, 'name': 'Liverpool'}
# 29          {'id': 24, 'name': 'Liverpool'}
# 30          {'id': 24, 'name': 'Liverpool'}
# 31          {'id': 24, 'name': 'Liverpool'}
# 32          {'id': 24, 'name': 'Liverpool'}
# 33          {'id': 24, 'name': 'Liverpool'}
#
#                           play_pattern  ... clearance  foul_won interception  \
# 0    {'id': 1, 'name': 'Regular Play'}  ...       NaN       NaN          NaN
# 1    {'id': 1, 'name': 'Regular Play'}  ...       NaN       NaN          NaN
# 2    {'id': 1, 'name': 'Regular Play'}  ...       NaN       NaN          NaN
# 3    {'id': 1, 'name': 'Regular Play'}  ...       NaN       NaN          NaN
# 4   {'id': 9, 'name': 'From Kick Off'}  ...       NaN       NaN          NaN
# 5   {'id': 9, 'name': 'From Kick Off'}  ...       NaN       NaN          NaN
# 6   {'id': 9, 'name': 'From Kick Off'}  ...       NaN       NaN          NaN
# 7   {'id': 9, 'name': 'From Kick Off'}  ...       NaN       NaN          NaN
# 8   {'id': 9, 'name': 'From Kick Off'}  ...       NaN       NaN          NaN
# 9   {'id': 9, 'name': 'From Kick Off'}  ...       NaN       NaN          NaN
# 10  {'id': 9, 'name': 'From Kick Off'}  ...       NaN       NaN          NaN
# 11  {'id': 9, 'name': 'From Kick Off'}  ...       NaN       NaN          NaN
# 12  {'id': 9, 'name': 'From Kick Off'}  ...       NaN       NaN          NaN
# 13  {'id': 9, 'name': 'From Kick Off'}  ...       NaN       NaN          NaN
# 14  {'id': 9, 'name': 'From Kick Off'}  ...       NaN       NaN          NaN
# 15  {'id': 9, 'name': 'From Kick Off'}  ...       NaN       NaN          NaN
# 16  {'id': 9, 'name': 'From Kick Off'}  ...       NaN       NaN          NaN
# 17  {'id': 9, 'name': 'From Kick Off'}  ...       NaN       NaN          NaN
# 18  {'id': 9, 'name': 'From Kick Off'}  ...       NaN       NaN          NaN
# 19  {'id': 9, 'name': 'From Kick Off'}  ...       NaN       NaN          NaN
# 20  {'id': 9, 'name': 'From Kick Off'}  ...       NaN       NaN          NaN
# 21  {'id': 9, 'name': 'From Kick Off'}  ...       NaN       NaN          NaN
# 22  {'id': 9, 'name': 'From Kick Off'}  ...       NaN       NaN          NaN
# 23  {'id': 9, 'name': 'From Kick Off'}  ...       NaN       NaN          NaN
# 24  {'id': 9, 'name': 'From Kick Off'}  ...       NaN       NaN          NaN
# 25  {'id': 9, 'name': 'From Kick Off'}  ...       NaN       NaN          NaN
# 26  {'id': 9, 'name': 'From Kick Off'}  ...       NaN       NaN          NaN
# 27  {'id': 9, 'name': 'From Kick Off'}  ...       NaN       NaN          NaN
# 28  {'id': 9, 'name': 'From Kick Off'}  ...       NaN       NaN          NaN
# 29  {'id': 9, 'name': 'From Kick Off'}  ...       NaN       NaN          NaN
# 30  {'id': 9, 'name': 'From Kick Off'}  ...       NaN       NaN          NaN
# 31  {'id': 9, 'name': 'From Kick Off'}  ...       NaN       NaN          NaN
# 32  {'id': 9, 'name': 'From Kick Off'}  ...       NaN       NaN          NaN
# 33          {'id': 5, 'name': 'Other'}  ...       NaN       NaN          NaN
#
#    ball_recovery counterpress out dribble 50_50 substitution block
# 0            NaN          NaN NaN     NaN   NaN          NaN   NaN
# 1            NaN          NaN NaN     NaN   NaN          NaN   NaN
# 2            NaN          NaN NaN     NaN   NaN          NaN   NaN
# 3            NaN          NaN NaN     NaN   NaN          NaN   NaN
# 4            NaN          NaN NaN     NaN   NaN          NaN   NaN
# 5            NaN          NaN NaN     NaN   NaN          NaN   NaN
# 6            NaN          NaN NaN     NaN   NaN          NaN   NaN
# 7            NaN          NaN NaN     NaN   NaN          NaN   NaN
# 8            NaN          NaN NaN     NaN   NaN          NaN   NaN
# 9            NaN          NaN NaN     NaN   NaN          NaN   NaN
# 10           NaN          NaN NaN     NaN   NaN          NaN   NaN
# 11           NaN          NaN NaN     NaN   NaN          NaN   NaN
# 12           NaN          NaN NaN     NaN   NaN          NaN   NaN
# 13           NaN          NaN NaN     NaN   NaN          NaN   NaN
# 14           NaN          NaN NaN     NaN   NaN          NaN   NaN
# 15           NaN          NaN NaN     NaN   NaN          NaN   NaN
# 16           NaN          NaN NaN     NaN   NaN          NaN   NaN
# 17           NaN          NaN NaN     NaN   NaN          NaN   NaN
# 18           NaN          NaN NaN     NaN   NaN          NaN   NaN
# 19           NaN          NaN NaN     NaN   NaN          NaN   NaN
# 20           NaN          NaN NaN     NaN   NaN          NaN   NaN
# 21           NaN          NaN NaN     NaN   NaN          NaN   NaN
# 22           NaN          NaN NaN     NaN   NaN          NaN   NaN
# 23           NaN          NaN NaN     NaN   NaN          NaN   NaN
# 24           NaN          NaN NaN     NaN   NaN          NaN   NaN
# 25           NaN          NaN NaN     NaN   NaN          NaN   NaN
# 26           NaN          NaN NaN     NaN   NaN          NaN   NaN
# 27           NaN          NaN NaN     NaN   NaN          NaN   NaN
# 28           NaN          NaN NaN     NaN   NaN          NaN   NaN
# 29           NaN          NaN NaN     NaN   NaN          NaN   NaN
# 30           NaN          NaN NaN     NaN   NaN          NaN   NaN
# 31           NaN          NaN NaN     NaN   NaN          NaN   NaN
# 32           NaN          NaN NaN     NaN   NaN          NaN   NaN
# 33           NaN          NaN NaN     NaN   NaN          NaN   NaN
#
# [34 rows x 36 columns]

# %%
# list(events_df.iloc[33].reset_index().iloc[23])
# events_df.iloc[33].reset_index()
"""
Function for type of play: goal, pass,etc
"""
def get_shot_type(type_dict):
    return type_dict.get('name')

# %%
# unpacking type column dictionary for knowing type of play.
events_df['shot_type'] = events_df['type'].apply(get_shot_type)

events_df.iloc[33]['shot_type']

total_shots_df = events_df[events_df['shot_type'] == 'Shot']

# All shots in first half of the game. period = 1 .. 2nd half means period = 2
first_half_shots = total_shots_df[total_shots_df['period'] == 1]

# %%
first_half_shots.head()
# Out:
#                                        id  index  period  \
# 33   642e3db4-bfa4-4ed2-9a22-468e68bd6e0a     34       1
# 341  93adc671-0697-4ad0-8f30-6dea062f3b03    342       1
# 586  e18a3a5e-b587-43f3-8dea-a25a14517c14    587       1
# 757  2439947c-b340-48a3-a8fe-b4e217136ccd    758       1
# 767  7c1825a8-ff22-4d87-9a58-b287f0f3104a    768       1
#
#                   timestamp  minute  second                        type  \
# 33  2020-07-04 00:01:48.568       1      48  {'id': 16, 'name': 'Shot'}
# 341 2020-07-04 00:09:04.723       9       4  {'id': 16, 'name': 'Shot'}
# 586 2020-07-04 00:16:48.573      16      48  {'id': 16, 'name': 'Shot'}
# 757 2020-07-04 00:20:31.085      20      31  {'id': 16, 'name': 'Shot'}
# 767 2020-07-04 00:21:53.381      21      53  {'id': 16, 'name': 'Shot'}
#
#      possession                          possession_team  \
# 33            3          {'id': 24, 'name': 'Liverpool'}
# 341          15  {'id': 38, 'name': 'Tottenham Hotspur'}
# 586          25          {'id': 24, 'name': 'Liverpool'}
# 757          35          {'id': 24, 'name': 'Liverpool'}
# 767          37          {'id': 24, 'name': 'Liverpool'}
#
#                            play_pattern  ... foul_won  interception  \
# 33           {'id': 5, 'name': 'Other'}  ...      NaN           NaN
# 341   {'id': 1, 'name': 'Regular Play'}  ...      NaN           NaN
# 586  {'id': 4, 'name': 'From Throw In'}  ...      NaN           NaN
# 757    {'id': 8, 'name': 'From Keeper'}  ...      NaN           NaN
# 767  {'id': 4, 'name': 'From Throw In'}  ...      NaN           NaN
#
#     ball_recovery counterpress  out dribble 50_50 substitution block shot_type
# 33            NaN          NaN  NaN     NaN   NaN          NaN   NaN      Shot
# 341           NaN          NaN  NaN     NaN   NaN          NaN   NaN      Shot
# 586           NaN          NaN  NaN     NaN   NaN          NaN   NaN      Shot
# 757           NaN          NaN  NaN     NaN   NaN          NaN   NaN      Shot
# 767           NaN          NaN  1.0     NaN   NaN          NaN   NaN      Shot
#
# [5 rows x 37 columns]

# %%
def get_team_name(possession_team_dict):
    return possession_team_dict.get('name')

# %%
shot_details_1st_df = pd.DataFrame(first_half_shots['location'])

shot_details_1st_df['shot_details'] = pd.DataFrame(first_half_shots['shot'])
shot_details_1st_df['team'] = pd.DataFrame(first_half_shots['possession_team'].apply(get_team_name))

# %%
shot_details_1st_df.head()
# Out:
#           location                                       shot_details  \
# 33   [108.2, 40.1]  {'statsbomb_xg': 0.76, 'end_location': [120.0,...
# 341   [91.9, 43.1]  {'statsbomb_xg': 0.022700306, 'end_location': ...
# 586   [90.2, 59.3]  {'statsbomb_xg': 0.011111712000000001, 'end_lo...
# 757   [95.2, 47.2]  {'statsbomb_xg': 0.038991462000000005, 'end_lo...
# 767  [113.0, 59.5]  {'statsbomb_xg': 0.014388007000000001, 'end_lo...
#
#                   team
# 33           Liverpool
# 341  Tottenham Hotspur
# 586          Liverpool
# 757          Liverpool
# 767          Liverpool

# %%
def get_shot_end_location(shot_details_dict):
    return shot_details_dict.get('end_location')

def get_shot_outcome(shot_details_dict):
    return shot_details_dict.get('outcome')
    
def get_shot_type(shot_details_dict):
    return shot_details_dict.get('type')

# %%
shot_details_1st_df['end_location'] = shot_details_1st_df['shot_details'].apply(get_shot_end_location)

# %%
shot_details_1st_df['outcome'] = shot_details_1st_df['shot_details'].apply(get_shot_outcome)

# %%
shot_details_1st_df['type'] = shot_details_1st_df['shot_details'].apply(get_shot_type)

# %%
shot_details_1st_df
# Out:
#            location                                       shot_details  \
# 33    [108.2, 40.1]  {'statsbomb_xg': 0.76, 'end_location': [120.0,...
# 341    [91.9, 43.1]  {'statsbomb_xg': 0.022700306, 'end_location': ...
# 586    [90.2, 59.3]  {'statsbomb_xg': 0.011111712000000001, 'end_lo...
# 757    [95.2, 47.2]  {'statsbomb_xg': 0.038991462000000005, 'end_lo...
# 767   [113.0, 59.5]  {'statsbomb_xg': 0.014388007000000001, 'end_lo...
# 1346   [98.4, 20.4]  {'statsbomb_xg': 0.012589856, 'end_location': ...
# 1352   [97.6, 37.4]  {'statsbomb_xg': 0.02638541, 'end_location': [...
# 1401   [89.0, 47.9]  {'statsbomb_xg': 0.015078909000000001, 'end_lo...
# 1422   [94.0, 31.3]  {'statsbomb_xg': 0.01395537, 'end_location': [...
# 1560   [96.1, 41.6]  {'statsbomb_xg': 0.03756312, 'end_location': [...
#
#                    team        end_location                         outcome  \
# 33            Liverpool  [120.0, 42.5, 0.9]      {'id': 97, 'name': 'Goal'}
# 341   Tottenham Hotspur  [120.0, 46.5, 5.2]     {'id': 98, 'name': 'Off T'}
# 586           Liverpool  [120.0, 34.7, 0.8]     {'id': 98, 'name': 'Off T'}
# 757           Liverpool        [99.7, 46.2]   {'id': 96, 'name': 'Blocked'}
# 767           Liverpool        [113.2, 0.1]  {'id': 101, 'name': 'Wayward'}
# 1346          Liverpool  [118.3, 37.9, 2.4]    {'id': 100, 'name': 'Saved'}
# 1352          Liverpool  [120.0, 43.3, 6.4]     {'id': 98, 'name': 'Off T'}
# 1401          Liverpool        [96.1, 46.2]   {'id': 96, 'name': 'Blocked'}
# 1422          Liverpool        [97.2, 32.8]   {'id': 96, 'name': 'Blocked'}
# 1560  Tottenham Hotspur  [120.0, 37.2, 6.0]     {'id': 98, 'name': 'Off T'}
#
#                                  type
# 33      {'id': 88, 'name': 'Penalty'}
# 341   {'id': 87, 'name': 'Open Play'}
# 586   {'id': 87, 'name': 'Open Play'}
# 757   {'id': 87, 'name': 'Open Play'}
# 767   {'id': 87, 'name': 'Open Play'}
# 1346  {'id': 87, 'name': 'Open Play'}
# 1352  {'id': 87, 'name': 'Open Play'}
# 1401  {'id': 87, 'name': 'Open Play'}
# 1422  {'id': 87, 'name': 'Open Play'}
# 1560  {'id': 87, 'name': 'Open Play'}

# %%
len(shot_details_1st_df)
# Out:
# 10

# %%
# testing loop code
for i,row in shot_details_1st_df.iterrows():
    if row['outcome'].get('name') == 'Goal':
        print(i)
#     print(row['location'])
# Out:
# 33

# %% [markdown]
# # Colors for shot type:
#
# * goal : green
# * saved : red
# * blocked : yellow

# %%
#Draw the pitch (Using FcPython library)

(fig,ax) = createPitch(pitchLengthX,pitchWidthY,'yards','white')
# Plot the shot
circleSize = 2

for i,row in shot_details_1st_df.iterrows():
    x = row['location'][0] # shot taken x-axis
    y = row['location'][1]  # shot taken y-axis

    dx = row['end_location'][0] - x 
    dy = row['end_location'][1] - y 

    ## parameters for making the arrow
    pass_x = 120 - row['end_location'][0]
    pass_y = row['end_location'][1] 
    dx = ((pitchLengthX - x) - pass_x)
    dy = y - pass_y
    
    if row['outcome'].get('name') == 'Goal' :
        color = "red"
        goalIndex = i
    elif row['outcome'].get('name') == 'Saved':
        color = "green"
    elif row['outcome'].get('name') == 'Blocked':
        color = "yellow"
    else:
        color = "blue"
    
    if row['team'] == home_team_required:
        shotCircle = plt.Circle((pitchLengthX-x,y),circleSize,color = color)
        shotCircle.set_alpha(.2)
        passArrow = plt.arrow(pitchLengthX-x, y, -dx, -dy, width = 0.5 ,color = color)
        
    elif row['team'] == away_team_required:
        shotCircle = plt.Circle((x,pitchWidthY-y),circleSize,color = color)
        shotCircle.set_alpha(.2)
        passArrow = plt.arrow(x, pitchWidthY-y, dx, dy, width = 0.5 ,color = color)
    
    ax.add_patch(shotCircle)
    ax.set_facecolor('mediumseagreen')
    ax.add_patch(passArrow)        
        
plt.text(25, 6, 'Spurs(Left To Right) vs Liverpool(Right To Left)', fontsize=15)
fig.patch.set_facecolor('#006400')
fig.patch.set_alpha(0.7)
fig.set_size_inches(10, 7)
# savefig('figname.png', facecolor=fig.get_facecolor(), transparent=True)
fig.savefig('../Output/spursvslfc_ucl_final_1sthalf_goal.pdf',facecolor=fig.get_facecolor(), transparent=True,dpi=100) 
plt.show()
